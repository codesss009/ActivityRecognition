# %% [markdown]
# <h1 style=" text-align:center; font-size:40px;"> <u><b>Human Activity Recognition Using Neural Networks</b></u> </h1>
#
# <p style="text-align:center; ">
# <img src="https://dmtyylqvwgyxw.cloudfront.net/instances/132/uploads/images/custom_image/image/675/normal_Human_activity_recognition.jpg?v=1541506221" style='width: 800px;'>
# </p>

# %%
# About The Data

Description of experiment
The experiments have been carried out with a group of 30 volunteers within an age bracket of 19-48 years. Each person performed six activities (WALKING, WALKINGUPSTAIRS, WALKINGDOWNSTAIRS, SITTING, STANDING, LAYING) wearing a smartphone (Samsung Galaxy S II) on the waist. Using its embedded accelerometer and gyroscope, we captured 3-axial linear acceleration and 3-axial angular velocity at a constant rate of 50Hz. The experiments have been video-recorded to label the data manually. The obtained dataset has been randomly partitioned into two sets, where 70% of the volunteers was selected for generating the training data and 30% the test data.

The sensor signals (accelerometer and gyroscope) were pre-processed by applying noise filters and then sampled in fixed-width sliding windows of 2.56 sec and 50% overlap (128 readings/window). The sensor acceleration signal, which has gravitational and body motion components, was separated using a Butterworth low-pass filter into body acceleration and gravity. The gravitational force is assumed to have only low frequency components, therefore a filter with 0.3 Hz cutoff frequency was used. From each window, a vector of features was obtained by calculating variables from the time and frequency domain.

For each record in the dataset the following is provided:

* Triaxial acceleration from the accelerometer (total acceleration) and the estimated body acceleration.

* Triaxial Angular velocity from the gyroscope.

* A 561-feature vector with time and frequency domain variables.

* Its activity label.

* An identifier of the subject who carried out the experiment.

# %% [markdown]
# ## Importing The Modules

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras_tuner.tuners import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters
import os
import warnings
from tensorflow import keras
from tensorflow.keras import layers
from keras_tuner.tuners import RandomSearch
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading The Data

# %%
train_data = pd.read_csv('UCI HAR Dataset/train/train.csv')
test_data = pd.read_csv('UCI HAR Dataset/test/test.csv')

print(f'Shape of train data is: {train_data.shape}\nShape of test data is: {test_data.shape}')
# Out:
# Shape of train data is: (7352, 564)
# Shape of test data is: (2947, 564)

# %% [markdown]
# ## Some Analysis

# %%
pd.set_option("display.max_columns", None)

# %%
train_data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.175106          -0.066073          -0.203307         -0.029892
# 1           0.395002          -0.012474          -0.147287         -0.300226
# 2           0.268530          -0.013769          -0.079357         -0.988281
# 3          -0.503823          -0.594207           0.264804         -0.703402
# 4           0.276149           0.001509          -0.094874         -0.997953
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0          0.238056         -0.411581         -0.146498          0.172879
# 1         -0.134092         -0.279045         -0.309342         -0.163892
# 2         -0.955455         -0.926482         -0.988175         -0.951200
# 3          0.672487         -0.464985         -0.704548          0.967664
# 4         -0.949356         -0.968903         -0.998208         -0.943479
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  tBodyAcc-max()-Y  tBodyAcc-max()-Z  \
# 0         -0.400673          0.351852         -0.106676         -0.375972
# 1         -0.291077         -0.157089         -0.063288         -0.192386
# 2         -0.910283         -0.936119         -0.551010         -0.776662
# 3         -0.401827         -0.948813         -0.511096         -0.345057
# 4         -0.967106         -0.944875         -0.516286         -0.796682
#
#    tBodyAcc-min()-X  tBodyAcc-min()-Y  tBodyAcc-min()-Z  tBodyAcc-sma()  \
# 0          0.101252         -0.102434          0.405208       -0.017704
# 1          0.186682          0.101009          0.448644       -0.188687
# 2          0.841715          0.682173          0.834660       -0.954475
# 3          0.358381         -0.191547          0.844073        0.169265
# 4          0.849883          0.693631          0.839683       -0.972600
#
#    tBodyAcc-energy()-X  tBodyAcc-energy()-Y  tBodyAcc-energy()-Z  \
# 0            -0.526431            -0.700310            -0.827996
# 1            -0.751068            -0.854469            -0.761887
# 2            -0.999865            -0.999432            -0.995356
# 3            -0.832117             0.136684            -0.662831
# 4            -0.999989            -0.998692            -0.998869
#
#    tBodyAcc-iqr()-X  tBodyAcc-iqr()-Y  tBodyAcc-iqr()-Z  tBodyAcc-entropy()-X  \
# 0         -0.427957         -0.223200         -0.377802             -0.043471
# 1         -0.331049         -0.312898         -0.374151              0.423540
# 2         -0.986753         -0.955510         -0.890621             -0.541056
# 3         -0.689162          1.000000         -0.184065             -1.000000
# 4         -0.998243         -0.942677         -0.962730             -0.777403
#
#    tBodyAcc-entropy()-Y  tBodyAcc-entropy()-Z  tBodyAcc-arCoeff()-X,1  \
# 0              0.306354             -0.093503               -0.556603
# 1              0.270432              0.139547               -0.302848
# 2             -0.334029             -0.172859               -0.181061
# 3             -0.470942              0.706844               -0.563419
# 4             -0.071508             -0.218842                0.306421
#
#    tBodyAcc-arCoeff()-X,2  tBodyAcc-arCoeff()-X,3  tBodyAcc-arCoeff()-X,4  \
# 0                0.482424               -0.260594                0.162502
# 1                0.209104               -0.092687                0.193734
# 2                0.072288                0.068981               -0.106730
# 3                0.460859               -0.378995                0.191142
# 4                0.018086               -0.060779                0.196016
#
#    tBodyAcc-arCoeff()-Y,1  tBodyAcc-arCoeff()-Y,2  tBodyAcc-arCoeff()-Y,3  \
# 0               -0.423429                0.338683                0.005448
# 1               -0.325468                0.258891                0.148014
# 2                0.010759               -0.061863                0.053231
# 3               -0.748323                0.499146               -0.045553
# 4                0.035018               -0.023862               -0.014115
#
#    tBodyAcc-arCoeff()-Y,4  tBodyAcc-arCoeff()-Z,1  tBodyAcc-arCoeff()-Z,2  \
# 0               -0.011706               -0.251574                0.145000
# 1               -0.085158               -0.206097                0.256425
# 2                0.120707                0.208335               -0.176326
# 3               -0.045720               -0.379024                0.302409
# 4                0.083126                0.184546               -0.208915
#
#    tBodyAcc-arCoeff()-Z,3  tBodyAcc-arCoeff()-Z,4  tBodyAcc-correlation()-X,Y  \
# 0                0.156297               -0.249484                   -0.274698
# 1               -0.242481                0.123536                    0.111106
# 2                0.173616               -0.347923                   -0.802393
# 3               -0.536923                0.432875                    0.699676
# 4                0.191888               -0.163977                   -0.253756
#
#    tBodyAcc-correlation()-X,Z  tBodyAcc-correlation()-Y,Z  \
# 0                   -0.386649                    0.281635
# 1                    0.044764                    0.456726
# 2                   -0.847415                    0.813980
# 3                   -0.942769                   -0.833899
# 4                   -0.259192                    0.563918
#
#    tGravityAcc-mean()-X  tGravityAcc-mean()-Y  tGravityAcc-mean()-Z  \
# 0              0.938138             -0.305294              0.015105
# 1              0.953590             -0.218712             -0.106841
# 2              0.933265              0.107245              0.214537
# 3             -0.601241              0.736064              0.660976
# 4              0.973169             -0.001451             -0.068271
#
#    tGravityAcc-std()-X  tGravityAcc-std()-Y  tGravityAcc-std()-Z  \
# 0            -0.928983            -0.817971            -0.835381
# 1            -0.982919            -0.981730            -0.955562
# 2            -0.978008            -0.971187            -0.908329
# 3            -0.414672            -0.424784            -0.576882
# 4            -0.999315            -0.979150            -0.991910
#
#    tGravityAcc-mad()-X  tGravityAcc-mad()-Y  tGravityAcc-mad()-Z  \
# 0            -0.926888            -0.807459            -0.833920
# 1            -0.984305            -0.984126            -0.953500
# 2            -0.977560            -0.971509            -0.906364
# 3            -0.428806            -0.486424            -0.601582
# 4            -0.999306            -0.981563            -0.993091
#
#    tGravityAcc-max()-X  tGravityAcc-max()-Y  tGravityAcc-max()-Z  \
# 0             0.885511            -0.281334             0.039581
# 1             0.884381            -0.235084            -0.105917
# 2             0.867591             0.081982             0.219477
# 3            -0.557901             0.757431             0.811051
# 4             0.898459            -0.017633            -0.073896
#
#    tGravityAcc-min()-X  tGravityAcc-min()-Y  tGravityAcc-min()-Z  \
# 0             0.932296            -0.318758            -0.025974
# 1             0.965707            -0.196428            -0.114590
# 2             0.948857             0.120761             0.192721
# 3            -0.844615             0.426306             0.615155
# 4             0.992643             0.021084            -0.069324
#
#    tGravityAcc-sma()  tGravityAcc-energy()-X  tGravityAcc-energy()-Y  \
# 0          -0.207920                0.833550               -0.838574
# 1          -0.175572                0.873657               -0.922323
# 2          -0.161441                0.820719               -0.969645
# 3           0.275020               -0.969867                0.119977
# 4          -0.740673                0.925363               -0.999437
#
#    tGravityAcc-energy()-Z  tGravityAcc-iqr()-X  tGravityAcc-iqr()-Y  \
# 0               -0.998617            -0.935359            -0.780749
# 1               -0.974898            -0.988557            -0.990198
# 2               -0.913307            -0.976487            -0.974379
# 3               -0.142658            -0.500695            -0.720839
# 4               -0.989199            -0.999282            -0.989303
#
#    tGravityAcc-iqr()-Z  tGravityAcc-entropy()-X  tGravityAcc-entropy()-Y  \
# 0            -0.827651                -0.413531                -1.000000
# 1            -0.951930                -1.000000                -1.000000
# 2            -0.900270                -0.520164                -0.453789
# 3            -0.710104                -1.000000                 0.243617
# 4            -0.995114                -1.000000                -0.475715
#
#    tGravityAcc-entropy()-Z  tGravityAcc-arCoeff()-X,1  \
# 0                -0.078379                  -0.583367
# 1                -1.000000                  -0.370674
# 2                -0.026387                  -0.425593
# 3                 0.407477                  -0.984661
# 4                -1.000000                  -0.110682
#
#    tGravityAcc-arCoeff()-X,2  tGravityAcc-arCoeff()-X,3  \
# 0                   0.639498                  -0.695036
# 1                   0.435648                  -0.496312
# 2                   0.421939                  -0.418184
# 3                   0.986368                  -0.987700
# 4                   0.148719                  -0.187258
#
#    tGravityAcc-arCoeff()-X,4  tGravityAcc-arCoeff()-Y,1  \
# 0                   0.750005                  -0.499752
# 1                   0.552543                  -0.133542
# 2                   0.414481                  -0.548227
# 3                   0.988854                  -0.954655
# 4                   0.226346                  -0.563557
#
#    tGravityAcc-arCoeff()-Y,2  tGravityAcc-arCoeff()-Y,3  \
# 0                   0.510157                  -0.555947
# 1                   0.151931                  -0.228539
# 2                   0.504457                  -0.489338
# 3                   0.950436                  -0.949106
# 4                   0.523217                  -0.510563
#
#    tGravityAcc-arCoeff()-Y,4  tGravityAcc-arCoeff()-Z,1  \
# 0                   0.615323                  -0.497448
# 1                   0.325513                  -0.469944
# 2                   0.487476                  -0.630213
# 3                   0.949103                  -0.934009
# 4                   0.510566                  -0.735018
#
#    tGravityAcc-arCoeff()-Z,2  tGravityAcc-arCoeff()-Z,3  \
# 0                   0.514745                  -0.531618
# 1                   0.526070                  -0.581679
# 2                   0.626557                  -0.622506
# 3                   0.933509                  -0.932461
# 4                   0.740996                  -0.746484
#
#    tGravityAcc-arCoeff()-Z,4  tGravityAcc-correlation()-X,Y  \
# 0                   0.545437                       0.939449
# 1                   0.633817                       0.873824
# 2                   0.615281                      -0.971827
# 3                   0.927540                       0.958335
# 4                   0.748450                      -0.358413
#
#    tGravityAcc-correlation()-X,Z  tGravityAcc-correlation()-Y,Z  \
# 0                       0.957024                       0.883575
# 1                       0.698350                       0.582393
# 2                      -0.997998                       0.954273
# 3                      -0.992329                      -0.985639
# 4                       0.279348                       0.513936
#
#    tBodyAccJerk-mean()-X  tBodyAccJerk-mean()-Y  tBodyAccJerk-mean()-Z  \
# 0               0.157545              -0.130238               0.000459
# 1               0.159340               0.167232              -0.083333
# 2               0.080413              -0.001083              -0.029773
# 3               0.017755              -0.487384               0.086882
# 4               0.075922               0.007081               0.009322
#
#    tBodyAccJerk-std()-X  tBodyAccJerk-std()-Y  tBodyAccJerk-std()-Z  \
# 0             -0.089580             -0.118020             -0.647813
# 1             -0.325052             -0.253691             -0.518611
# 2             -0.993636             -0.987227             -0.991863
# 3             -0.943412             -0.867912             -0.935217
# 4             -0.994543             -0.975964             -0.992575
#
#    tBodyAccJerk-mad()-X  tBodyAccJerk-mad()-Y  tBodyAccJerk-mad()-Z  \
# 0             -0.135097             -0.157040             -0.666784
# 1             -0.285367             -0.203669             -0.493244
# 2             -0.993250             -0.985292             -0.990992
# 3             -0.941173             -0.865768             -0.934620
# 4             -0.994228             -0.973744             -0.991006
#
#    tBodyAccJerk-max()-X  tBodyAccJerk-max()-Y  tBodyAccJerk-max()-Z  \
# 0             -0.326239             -0.444459             -0.561202
# 1             -0.517864             -0.584353             -0.680893
# 2             -0.995036             -0.992891             -0.992730
# 3             -0.963848             -0.953522             -0.929677
# 4             -0.995678             -0.980014             -0.995342
#
#    tBodyAccJerk-min()-X  tBodyAccJerk-min()-Y  tBodyAccJerk-min()-Z  \
# 0             -0.395927              0.212781              0.727263
# 1              0.424178              0.467668              0.462904
# 2              0.992746              0.990678              0.989772
# 3              0.934969              0.845679              0.947081
# 4              0.994903              0.979746              0.990040
#
#    tBodyAccJerk-sma()  tBodyAccJerk-energy()-X  tBodyAccJerk-energy()-Y  \
# 0           -0.280140                -0.582938                -0.606244
# 1           -0.293654                -0.769573                -0.716927
# 2           -0.992154                -0.999936                -0.999795
# 3           -0.917536                -0.998015                -0.989326
# 4           -0.989283                -0.999948                -0.999482
#
#    tBodyAccJerk-energy()-Z  tBodyAccJerk-iqr()-X  tBodyAccJerk-iqr()-Y  \
# 0                -0.933693             -0.190457             -0.355753
# 1                -0.878722             -0.208791             -0.313984
# 2                -0.999846             -0.989483             -0.984591
# 3                -0.996964             -0.934986             -0.888837
# 4                -0.999863             -0.992531             -0.969301
#
#    tBodyAccJerk-iqr()-Z  tBodyAccJerk-entropy()-X  tBodyAccJerk-entropy()-Y  \
# 0             -0.723172                  0.808165                  0.654597
# 1             -0.507796                  0.660356                  0.705422
# 2             -0.990397                 -0.761244                 -0.783017
# 3             -0.939180                 -0.240865                 -0.284698
# 4             -0.989378                 -0.850744                 -0.595583
#
#    tBodyAccJerk-entropy()-Z  tBodyAccJerk-arCoeff()-X,1  \
# 0                  0.223366                   -0.534469
# 1                  0.658970                   -0.316694
# 2                 -0.785230                   -0.093990
# 3                 -0.235522                   -0.411250
# 4                 -0.783790                    0.240152
#
#    tBodyAccJerk-arCoeff()-X,2  tBodyAccJerk-arCoeff()-X,3  \
# 0                    0.321583                   -0.050742
# 1                    0.215910                   -0.154251
# 2                    0.260073                   -0.119410
# 3                    0.269557                   -0.070864
# 4                    0.433527                    0.179507
#
#    tBodyAccJerk-arCoeff()-X,4  tBodyAccJerk-arCoeff()-Y,1  \
# 0                   -0.029610                   -0.484498
# 1                    0.219759                   -0.430240
# 2                    0.535630                    0.024912
# 3                   -0.158431                   -0.683660
# 4                    0.344894                    0.015010
#
#    tBodyAccJerk-arCoeff()-Y,2  tBodyAccJerk-arCoeff()-Y,3  \
# 0                    0.246707                   -0.006779
# 1                    0.138169                    0.198278
# 2                    0.052574                   -0.034968
# 3                    0.116283                    0.109683
# 4                    0.203132                   -0.101049
#
#    tBodyAccJerk-arCoeff()-Y,4  tBodyAccJerk-arCoeff()-Z,1  \
# 0                    0.268239                   -0.221875
# 1                    0.259228                   -0.245511
# 2                    0.374346                    0.271330
# 3                   -0.105982                   -0.406869
# 4                    0.510004                    0.182323
#
#    tBodyAccJerk-arCoeff()-Z,2  tBodyAccJerk-arCoeff()-Z,3  \
# 0                    0.064718                   -0.090972
# 1                    0.192018                   -0.118312
# 2                    0.013871                    0.178654
# 3                    0.254818                   -0.593129
# 4                   -0.099968                    0.073348
#
#    tBodyAccJerk-arCoeff()-Z,4  tBodyAccJerk-correlation()-X,Y  \
# 0                    0.397015                       -0.284754
# 1                   -0.070016                        0.282289
# 2                    0.171790                       -0.505948
# 3                    0.017359                        0.098145
# 4                    0.142058                       -0.117920
#
#    tBodyAccJerk-correlation()-X,Z  tBodyAccJerk-correlation()-Y,Z  \
# 0                       -0.604594                        0.367186
# 1                        0.506727                        0.433107
# 2                        0.336363                       -0.001946
# 3                       -0.388222                       -0.084330
# 4                       -0.002093                        0.052598
#
#    tBodyGyro-mean()-X  tBodyGyro-mean()-Y  tBodyGyro-mean()-Z  \
# 0           -0.467583            0.089412            0.034100
# 1           -0.029771           -0.023371            0.034941
# 2           -0.028113           -0.081210            0.096078
# 3           -0.318239            0.036379           -0.125898
# 4           -0.026649           -0.069823            0.079003
#
#    tBodyGyro-std()-X  tBodyGyro-std()-Y  tBodyGyro-std()-Z  tBodyGyro-mad()-X  \
# 0          -0.558324          -0.470744          -0.153798          -0.592990
# 1          -0.551541          -0.564067          -0.367481          -0.577200
# 2          -0.996662          -0.967719          -0.985320          -0.996574
# 3          -0.672297          -0.901797          -0.547875          -0.653115
# 4          -0.992180          -0.979638          -0.965728          -0.991789
#
#    tBodyGyro-mad()-Y  tBodyGyro-mad()-Z  tBodyGyro-max()-X  tBodyGyro-max()-Y  \
# 0          -0.497899          -0.256048          -0.701868          -0.567726
# 1          -0.588055          -0.373008          -0.313634          -0.634876
# 2          -0.968934          -0.986311          -0.885119          -0.940144
# 3          -0.905508          -0.508123          -0.871280          -0.872580
# 4          -0.978093          -0.966189          -0.881158          -0.947308
#
#    tBodyGyro-max()-Z  tBodyGyro-min()-X  tBodyGyro-min()-Y  tBodyGyro-min()-Z  \
# 0           0.378385           0.105770           0.630967           0.379314
# 1          -0.217167           0.508971           0.661217           0.447478
# 2          -0.747471           0.844773           0.897975           0.817339
# 3          -0.623705           0.470941           0.885788           0.534041
# 4          -0.736974           0.841659           0.907904           0.808398
#
#    tBodyGyro-sma()  tBodyGyro-energy()-X  tBodyGyro-energy()-Y  \
# 0        -0.226083             -0.786663             -0.856655
# 1        -0.422445             -0.907991             -0.905233
# 2        -0.980571             -0.999990             -0.999398
# 3        -0.600972             -0.896582             -0.992910
# 4        -0.978061             -0.999958             -0.999741
#
#    tBodyGyro-energy()-Z  tBodyGyro-iqr()-X  tBodyGyro-iqr()-Y  \
# 0             -0.667363          -0.643129          -0.585815
# 1             -0.813054          -0.600633          -0.617627
# 2             -0.999804          -0.996621          -0.972483
# 3             -0.887089          -0.598321          -0.912112
# 4             -0.999299          -0.991016          -0.976041
#
#    tBodyGyro-iqr()-Z  tBodyGyro-entropy()-X  tBodyGyro-entropy()-Y  \
# 0          -0.484864              -0.768364               0.367663
# 1          -0.483858               0.039665               0.390970
# 2          -0.989633              -0.621738              -0.228359
# 3          -0.489435              -0.660225               0.488103
# 4          -0.969313              -0.402612              -0.261576
#
#    tBodyGyro-entropy()-Z  tBodyGyro-arCoeff()-X,1  tBodyGyro-arCoeff()-X,2  \
# 0               0.005347                -0.545102                 0.469989
# 1               0.018151                -0.337498                 0.226231
# 2              -0.243421                 0.106889                -0.042109
# 3               0.103264                -0.448153                 0.233832
# 4              -0.276755                 0.089482                -0.012453
#
#    tBodyGyro-arCoeff()-X,3  tBodyGyro-arCoeff()-X,4  tBodyGyro-arCoeff()-Y,1  \
# 0                -0.173958                 0.009575                -0.449627
# 1                 0.230820                -0.190607                -0.237930
# 2                 0.237635                -0.166663                -0.420734
# 3                -0.001359                 0.151579                -0.312813
# 4                 0.271706                -0.361470                -0.060424
#
#    tBodyGyro-arCoeff()-Y,2  tBodyGyro-arCoeff()-Y,3  tBodyGyro-arCoeff()-Y,4  \
# 0                 0.465994                -0.269373                 0.143865
# 1                 0.206308                -0.027431                 0.106284
# 2                 0.346289                -0.258435                 0.198744
# 3                 0.165371                -0.014521                 0.108815
# 4                -0.004384                 0.163060                -0.144659
#
#    tBodyGyro-arCoeff()-Z,1  tBodyGyro-arCoeff()-Z,2  tBodyGyro-arCoeff()-Z,3  \
# 0                -0.446327                 0.481573                -0.301653
# 1                -0.350151                 0.403999                -0.441911
# 2                -0.064157                 0.071146                -0.031789
# 3                -0.296325                 0.111751                -0.019896
# 4                 0.064262                -0.125314                 0.101334
#
#    tBodyGyro-arCoeff()-Z,4  tBodyGyro-correlation()-X,Y  \
# 0                 0.192714                     0.080072
# 1                 0.578124                    -0.067815
# 2                 0.068779                     0.060401
# 3                 0.197678                    -0.432773
# 4                 0.026652                    -0.456144
#
#    tBodyGyro-correlation()-X,Z  tBodyGyro-correlation()-Y,Z  \
# 0                    -0.500112                    -0.002371
# 1                     0.118185                     0.103569
# 2                    -0.267250                    -0.450996
# 3                     0.830930                    -0.435304
# 4                    -0.023049                    -0.683632
#
#    tBodyGyroJerk-mean()-X  tBodyGyroJerk-mean()-Y  tBodyGyroJerk-mean()-Z  \
# 0                0.067344               -0.058500               -0.117790
# 1               -0.113926                0.078394                0.107381
# 2               -0.098780               -0.043236               -0.043304
# 3               -0.136265               -0.054405               -0.100946
# 4               -0.100379               -0.042591               -0.049563
#
#    tBodyGyroJerk-std()-X  tBodyGyroJerk-std()-Y  tBodyGyroJerk-std()-Z  \
# 0              -0.451334              -0.588149              -0.178803
# 1              -0.440246              -0.699418              -0.466744
# 2              -0.996236              -0.992062              -0.990227
# 3              -0.901663              -0.969526              -0.929095
# 4              -0.989516              -0.992762              -0.992814
#
#    tBodyGyroJerk-mad()-X  tBodyGyroJerk-mad()-Y  tBodyGyroJerk-mad()-Z  \
# 0              -0.434780              -0.620135              -0.316059
# 1              -0.439138              -0.713220              -0.485250
# 2              -0.996238              -0.992303              -0.990603
# 3              -0.906637              -0.969417              -0.929529
# 4              -0.989323              -0.993069              -0.992499
#
#    tBodyGyroJerk-max()-X  tBodyGyroJerk-max()-Y  tBodyGyroJerk-max()-Z  \
# 0              -0.543022              -0.590353              -0.058774
# 1              -0.334255              -0.778106              -0.413482
# 2              -0.995454              -0.991898              -0.988216
# 3              -0.918863              -0.976090              -0.907779
# 4              -0.990022              -0.994609              -0.992494
#
#    tBodyGyroJerk-min()-X  tBodyGyroJerk-min()-Y  tBodyGyroJerk-min()-Z  \
# 0               0.511254               0.616620               0.167913
# 1               0.576251               0.754337               0.645236
# 2               0.995832               0.993949               0.993997
# 3               0.901491               0.976323               0.957951
# 4               0.988710               0.993649               0.994436
#
#    tBodyGyroJerk-sma()  tBodyGyroJerk-energy()-X  tBodyGyroJerk-energy()-Y  \
# 0            -0.499333                 -0.847748                 -0.914406
# 1            -0.585694                 -0.841730                 -0.954187
# 2            -0.993751                 -0.999978                 -0.999949
# 3            -0.943640                 -0.994784                 -0.999462
# 4            -0.992680                 -0.999903                 -0.999956
#
#    tBodyGyroJerk-energy()-Z  tBodyGyroJerk-iqr()-X  tBodyGyroJerk-iqr()-Y  \
# 0                 -0.660041              -0.441323              -0.625817
# 1                 -0.855500              -0.468799              -0.744992
# 2                 -0.999896              -0.996513              -0.993047
# 3                 -0.997088              -0.925276              -0.972087
# 4                 -0.999933              -0.987749              -0.993377
#
#    tBodyGyroJerk-iqr()-Z  tBodyGyroJerk-entropy()-X  \
# 0              -0.567316                   0.616801
# 1              -0.552286                   0.610466
# 2              -0.991574                  -0.757710
# 3              -0.930985                   0.079256
# 4              -0.991985                  -0.527075
#
#    tBodyGyroJerk-entropy()-Y  tBodyGyroJerk-entropy()-Z  \
# 0                   0.490531                   0.612553
# 1                   0.669332                   0.526179
# 2                  -0.507515                  -0.508786
# 3                  -0.041288                   0.014330
# 4                  -0.535992                  -0.618882
#
#    tBodyGyroJerk-arCoeff()-X,1  tBodyGyroJerk-arCoeff()-X,2  \
# 0                    -0.404957                     0.433611
# 1                    -0.197305                     0.062084
# 2                     0.273968                    -0.005865
# 3                    -0.259720                    -0.008070
# 4                     0.271444                     0.065156
#
#    tBodyGyroJerk-arCoeff()-X,3  tBodyGyroJerk-arCoeff()-X,4  \
# 0                    -0.322998                     0.516011
# 1                     0.219219                     0.241208
# 2                     0.413851                     0.048828
# 3                    -0.111965                     0.068700
# 4                     0.489298                     0.123931
#
#    tBodyGyroJerk-arCoeff()-Y,1  tBodyGyroJerk-arCoeff()-Y,2  \
# 0                    -0.402865                     0.415445
# 1                    -0.203093                     0.286376
# 2                    -0.315231                     0.267500
# 3                    -0.196279                     0.039908
# 4                     0.055380                     0.161958
#
#    tBodyGyroJerk-arCoeff()-Y,3  tBodyGyroJerk-arCoeff()-Y,4  \
# 0                     0.064371                    -0.068975
# 1                     0.009904                     0.306966
# 2                     0.020207                    -0.181814
# 3                     0.188000                    -0.366210
# 4                     0.202701                     0.363063
#
#    tBodyGyroJerk-arCoeff()-Z,1  tBodyGyroJerk-arCoeff()-Z,2  \
# 0                    -0.432831                     0.423768
# 1                    -0.425490                     0.335717
# 2                     0.016698                     0.092928
# 3                    -0.152101                    -0.133806
# 4                     0.192820                    -0.136675
#
#    tBodyGyroJerk-arCoeff()-Z,3  tBodyGyroJerk-arCoeff()-Z,4  \
# 0                    -0.061660                     0.025282
# 1                    -0.213837                    -0.100862
# 2                     0.137631                    -0.056550
# 3                     0.142965                    -0.422430
# 4                     0.251929                    -0.187296
#
#    tBodyGyroJerk-correlation()-X,Y  tBodyGyroJerk-correlation()-X,Z  \
# 0                         0.126933                        -0.296031
# 1                         0.179717                         0.044469
# 2                        -0.141358                         0.185519
# 3                        -0.280746                         0.272598
# 4                        -0.385437                         0.376694
#
#    tBodyGyroJerk-correlation()-Y,Z  tBodyAccMag-mean()  tBodyAccMag-std()  \
# 0                        -0.152986            0.001941           0.066121
# 1                        -0.032299           -0.187880          -0.378027
# 2                         0.175921           -0.954681          -0.959592
# 3                         0.124372            0.130886           0.553535
# 4                        -0.060692           -0.970775          -0.956044
#
#    tBodyAccMag-mad()  tBodyAccMag-max()  tBodyAccMag-min()  tBodyAccMag-sma()  \
# 0          -0.035009           0.181303          -0.601676           0.001941
# 1          -0.424501          -0.250535          -0.540067          -0.187880
# 2          -0.959191          -0.965847          -0.979329          -0.954681
# 3           0.659538          -0.154079          -0.943962           0.130886
# 4          -0.954421          -0.959729          -0.995539          -0.970775
#
#    tBodyAccMag-energy()  tBodyAccMag-iqr()  tBodyAccMag-entropy()  \
# 0             -0.435380          -0.195765               0.854711
# 1             -0.670788          -0.445050               0.754437
# 2             -0.998395          -0.957865              -0.293460
# 3             -0.166026           0.857834               0.744819
# 4             -0.999012          -0.949517              -0.332827
#
#    tBodyAccMag-arCoeff()1  tBodyAccMag-arCoeff()2  tBodyAccMag-arCoeff()3  \
# 0               -0.321243                0.241427               -0.264967
# 1               -0.132477                0.071142                0.143384
# 2               -0.127064                0.097303               -0.133189
# 3               -0.887643                0.794398               -0.912329
# 4               -0.243864                0.229338               -0.222261
#
#    tBodyAccMag-arCoeff()4  tGravityAccMag-mean()  tGravityAccMag-std()  \
# 0                0.340978               0.001941              0.066121
# 1               -0.220127              -0.187880             -0.378027
# 2                0.097551              -0.954681             -0.959592
# 3                0.770750               0.130886              0.553535
# 4                0.098860              -0.970775             -0.956044
#
#    tGravityAccMag-mad()  tGravityAccMag-max()  tGravityAccMag-min()  \
# 0             -0.035009              0.181303             -0.601676
# 1             -0.424501             -0.250535             -0.540067
# 2             -0.959191             -0.965847             -0.979329
# 3              0.659538             -0.154079             -0.943962
# 4             -0.954421             -0.959729             -0.995539
#
#    tGravityAccMag-sma()  tGravityAccMag-energy()  tGravityAccMag-iqr()  \
# 0              0.001941                -0.435380             -0.195765
# 1             -0.187880                -0.670788             -0.445050
# 2             -0.954681                -0.998395             -0.957865
# 3              0.130886                -0.166026              0.857834
# 4             -0.970775                -0.999012             -0.949517
#
#    tGravityAccMag-entropy()  tGravityAccMag-arCoeff()1  \
# 0                  0.854711                  -0.321243
# 1                  0.754437                  -0.132477
# 2                 -0.293460                  -0.127064
# 3                  0.744819                  -0.887643
# 4                 -0.332827                  -0.243864
#
#    tGravityAccMag-arCoeff()2  tGravityAccMag-arCoeff()3  \
# 0                   0.241427                  -0.264967
# 1                   0.071142                   0.143384
# 2                   0.097303                  -0.133189
# 3                   0.794398                  -0.912329
# 4                   0.229338                  -0.222261
#
#    tGravityAccMag-arCoeff()4  tBodyAccJerkMag-mean()  tBodyAccJerkMag-std()  \
# 0                   0.340978               -0.258501              -0.046208
# 1                  -0.220127               -0.301036              -0.387440
# 2                   0.097551               -0.992038              -0.994455
# 3                   0.770750               -0.918462              -0.901825
# 4                   0.098860               -0.989468              -0.990431
#
#    tBodyAccJerkMag-mad()  tBodyAccJerkMag-max()  tBodyAccJerkMag-min()  \
# 0              -0.133485               0.126051              -0.653610
# 1              -0.389288              -0.439751              -0.377673
# 2              -0.994467              -0.995069              -0.986395
# 3              -0.911771              -0.897449              -0.931792
# 4              -0.991387              -0.989730              -0.987984
#
#    tBodyAccJerkMag-sma()  tBodyAccJerkMag-energy()  tBodyAccJerkMag-iqr()  \
# 0              -0.258501                 -0.660349              -0.263531
# 1              -0.301036                 -0.760387              -0.380643
# 2              -0.992038                 -0.999873              -0.993934
# 3              -0.918462                 -0.995058              -0.926988
# 4              -0.989468                 -0.999807              -0.993157
#
#    tBodyAccJerkMag-entropy()  tBodyAccJerkMag-arCoeff()1  \
# 0                   0.732563                   -0.297367
# 1                   0.739538                    0.192167
# 2                  -0.845492                    0.324432
# 3                  -0.146776                   -0.195155
# 4                  -0.834585                    0.182959
#
#    tBodyAccJerkMag-arCoeff()2  tBodyAccJerkMag-arCoeff()3  \
# 0                    0.360792                   -0.287342
# 1                   -0.088426                   -0.294549
# 2                   -0.132819                   -0.102274
# 3                    0.318233                   -0.302417
# 4                   -0.153363                   -0.157496
#
#    tBodyAccJerkMag-arCoeff()4  tBodyGyroMag-mean()  tBodyGyroMag-std()  \
# 0                    0.192975            -0.226474           -0.329707
# 1                    0.089015            -0.431392           -0.567552
# 2                   -0.276128            -0.978436           -0.975581
# 3                    0.035532            -0.588611           -0.484635
# 4                    0.075676            -0.978662           -0.981841
#
#    tBodyGyroMag-mad()  tBodyGyroMag-max()  tBodyGyroMag-min()  \
# 0           -0.352989           -0.279586           -0.540013
# 1           -0.517421           -0.583011           -0.605987
# 2           -0.972309           -0.982561           -0.982207
# 3           -0.387001           -0.652306           -0.830926
# 4           -0.978623           -0.986048           -0.980628
#
#    tBodyGyroMag-sma()  tBodyGyroMag-energy()  tBodyGyroMag-iqr()  \
# 0           -0.226474              -0.686455           -0.490045
# 1           -0.431392              -0.837104           -0.555965
# 2           -0.978436              -0.999628           -0.970737
# 3           -0.588611              -0.892600           -0.440210
# 4           -0.978662              -0.999673           -0.976346
#
#    tBodyGyroMag-entropy()  tBodyGyroMag-arCoeff()1  tBodyGyroMag-arCoeff()2  \
# 0                0.826217                -0.195705                 0.109289
# 1                0.941699                -0.084470                -0.018153
# 2               -0.038356                -0.180914                 0.012214
# 3                0.849837                -0.561265                 0.395181
# 4               -0.118534                 0.132789                -0.342309
#
#    tBodyGyroMag-arCoeff()3  tBodyGyroMag-arCoeff()4  tBodyGyroJerkMag-mean()  \
# 0                -0.027749                 0.034797                -0.498021
# 1                 0.218376                -0.286484                -0.589563
# 2                 0.162308                -0.094865                -0.993228
# 3                -0.323930                 0.436454                -0.943539
# 4                 0.620722                -0.562152                -0.992721
#
#    tBodyGyroJerkMag-std()  tBodyGyroJerkMag-mad()  tBodyGyroJerkMag-max()  \
# 0               -0.486782               -0.520676               -0.592230
# 1               -0.635929               -0.635279               -0.666745
# 2               -0.994153               -0.994430               -0.993046
# 3               -0.946351               -0.948201               -0.950433
# 4               -0.993597               -0.993692               -0.994092
#
#    tBodyGyroJerkMag-min()  tBodyGyroJerkMag-sma()  tBodyGyroJerkMag-energy()  \
# 0               -0.597667               -0.498021                  -0.865664
# 1               -0.529470               -0.589563                  -0.917257
# 2               -0.994453               -0.993228                  -0.999951
# 3               -0.934141               -0.943539                  -0.998169
# 4               -0.992117               -0.992721                  -0.999945
#
#    tBodyGyroJerkMag-iqr()  tBodyGyroJerkMag-entropy()  \
# 0               -0.594717                    0.904323
# 1               -0.604030                    0.827596
# 2               -0.993808                   -0.600522
# 3               -0.947571                    0.172093
# 4               -0.992993                   -0.545943
#
#    tBodyGyroJerkMag-arCoeff()1  tBodyGyroJerkMag-arCoeff()2  \
# 0                     0.223927                    -0.146550
# 1                     0.170343                    -0.316090
# 2                     0.404298                    -0.287786
# 3                    -0.017735                     0.135827
# 4                     0.464132                    -0.449574
#
#    tBodyGyroJerkMag-arCoeff()3  tBodyGyroJerkMag-arCoeff()4  \
# 0                    -0.340882                     0.168615
# 1                     0.406081                    -0.334026
# 2                    -0.118173                    -0.079277
# 3                    -0.109447                    -0.251797
# 4                     0.053913                    -0.093099
#
#    fBodyAcc-mean()-X  fBodyAcc-mean()-Y  fBodyAcc-mean()-Z  fBodyAcc-std()-X  \
# 0          -0.066954           0.082062          -0.480216         -0.015646
# 1          -0.276121          -0.148404          -0.320789         -0.309888
# 2          -0.990375          -0.969187          -0.964537         -0.987254
# 3          -0.854914          -0.094850          -0.788758         -0.661182
# 4          -0.997366          -0.966178          -0.982399         -0.998231
#
#    fBodyAcc-std()-Y  fBodyAcc-std()-Z  fBodyAcc-mad()-X  fBodyAcc-mad()-Y  \
# 0          0.236433         -0.420062          0.052674          0.197340
# 1         -0.180997         -0.312703         -0.178639         -0.061450
# 2         -0.950977         -0.914010         -0.988720         -0.962024
# 3          0.860339         -0.380837         -0.815079          0.013555
# 4         -0.944026         -0.963359         -0.997146         -0.964947
#
#    fBodyAcc-mad()-Z  fBodyAcc-max()-X  fBodyAcc-max()-Y  fBodyAcc-max()-Z  \
# 0         -0.402438         -0.113405          0.004787         -0.391574
# 1         -0.248947         -0.518452         -0.520349         -0.502005
# 2         -0.955536         -0.985590         -0.952132         -0.882969
# 3         -0.709236         -0.620397          1.000000         -0.183852
# 4         -0.975394         -0.998909         -0.936447         -0.947950
#
#    fBodyAcc-min()-X  fBodyAcc-min()-Y  fBodyAcc-min()-Z  fBodyAcc-sma()  \
# 0         -0.891014         -0.953704         -0.931330       -0.018714
# 1         -0.876367         -0.784749         -0.782039       -0.142285
# 2         -0.997242         -0.984488         -0.980617       -0.976804
# 3         -0.959544          0.199564         -0.952768       -0.580092
# 4         -0.995999         -0.995013         -0.986002       -0.985502
#
#    fBodyAcc-energy()-X  fBodyAcc-energy()-Y  fBodyAcc-energy()-Z  \
# 0            -0.527336            -0.228868            -0.820009
# 1            -0.753208            -0.620160            -0.732480
# 2            -0.999881            -0.998570            -0.996126
# 3            -0.954922             0.401432            -0.850393
# 4            -0.999989            -0.998222            -0.999010
#
#    fBodyAcc-iqr()-X  fBodyAcc-iqr()-Y  fBodyAcc-iqr()-Z  fBodyAcc-entropy()-X  \
# 0          0.001053         -0.120895         -0.432218              0.717951
# 1         -0.432360         -0.348135         -0.474844              0.465813
# 2         -0.990103         -0.984852         -0.984878             -0.946357
# 3         -0.935876         -0.802706         -0.930498             -0.310541
# 4         -0.992678         -0.976555         -0.985380             -1.000000
#
#    fBodyAcc-entropy()-Y  fBodyAcc-entropy()-Z  fBodyAcc-maxInds-X  \
# 0              0.574778              0.317980           -0.806452
# 1              0.499639              0.468715           -0.806452
# 2             -0.732819             -0.813513           -1.000000
# 3              0.059830             -0.261317           -1.000000
# 4             -0.815786             -0.848109           -0.354839
#
#    fBodyAcc-maxInds-Y  fBodyAcc-maxInds-Z  fBodyAcc-meanFreq()-X  \
# 0           -0.800000           -0.923077              -0.496902
# 1           -0.466667           -0.692308              -0.417549
# 2           -1.000000           -1.000000              -0.393685
# 3           -1.000000           -1.000000              -0.815023
# 4           -1.000000           -1.000000               0.235535
#
#    fBodyAcc-meanFreq()-Y  fBodyAcc-meanFreq()-Z  fBodyAcc-skewness()-X  \
# 0              -0.244843              -0.207545              -0.004908
# 1              -0.099827              -0.058610              -0.278835
# 2              -0.400879              -0.217487               0.255988
# 3              -0.325093              -0.617481               0.920814
# 4              -0.157753              -0.147708              -0.662144
#
#    fBodyAcc-kurtosis()-X  fBodyAcc-skewness()-Y  fBodyAcc-kurtosis()-Y  \
# 0              -0.368854              -0.194059              -0.551217
# 1              -0.703858              -0.550719              -0.877281
# 2              -0.013869               0.118466              -0.211699
# 3               0.886393               0.824439               0.751161
# 4              -0.937150               0.620271               0.496372
#
#    fBodyAcc-skewness()-Z  fBodyAcc-kurtosis()-Z  fBodyAcc-bandsEnergy()-1,83  \
# 0              -0.205119              -0.439078                    -0.510881
# 1              -0.536997              -0.816932                    -0.755958
# 2               0.696464               0.591485                    -0.999870
# 3               0.969142               0.961044                    -0.938029
# 4               0.383333               0.216260                    -0.999996
#
#    fBodyAcc-bandsEnergy()-9,163  fBodyAcc-bandsEnergy()-17,243  \
# 0                     -0.655950                      -0.642069
# 1                     -0.790736                      -0.876251
# 2                     -0.999906                      -0.999947
# 3                     -0.998537                      -0.997939
# 4                     -0.999985                      -0.999932
#
#    fBodyAcc-bandsEnergy()-25,323  fBodyAcc-bandsEnergy()-33,403  \
# 0                      -0.796840                      -0.917436
# 1                      -0.765115                      -0.860916
# 2                      -0.999954                      -0.999928
# 3                      -0.996910                      -0.996195
# 4                      -0.999888                      -0.999897
#
#    fBodyAcc-bandsEnergy()-41,483  fBodyAcc-bandsEnergy()-49,563  \
# 0                      -0.883675                      -0.923541
# 1                      -0.852800                      -0.960211
# 2                      -0.999948                      -0.999981
# 3                      -0.998279                      -0.996050
# 4                      -0.999959                      -0.999977
#
#    fBodyAcc-bandsEnergy()-57,643  fBodyAcc-bandsEnergy()-1,163  \
# 0                      -0.995076                     -0.508171
# 1                      -0.964250                     -0.743535
# 2                      -0.999972                     -0.999871
# 3                      -0.994238                     -0.950092
# 4                      -0.999998                     -0.999995
#
#    fBodyAcc-bandsEnergy()-17,323  fBodyAcc-bandsEnergy()-33,483  \
# 0                      -0.632228                      -0.904795
# 1                      -0.823703                      -0.857888
# 2                      -0.999947                      -0.999950
# 3                      -0.997315                      -0.996991
# 4                      -0.999914                      -0.999936
#
#    fBodyAcc-bandsEnergy()-49,643  fBodyAcc-bandsEnergy()-1,243  \
# 0                      -0.947517                     -0.517689
# 1                      -0.961565                     -0.752970
# 2                      -0.999978                     -0.999878
# 3                      -0.995443                     -0.953494
# ...
# 1                      -0.958889                       -0.975271
# 2                      -0.999962                       -0.999970
# 3                      -0.999624                       -0.999779
# 4                      -0.999986                       -0.999964
#
#    fBodyGyro-bandsEnergy()-25,322  fBodyGyro-bandsEnergy()-33,402  \
# 0                       -0.966833                       -0.989513
# 1                       -0.959836                       -0.982877
# 2                       -0.999976                       -0.999978
# 3                       -0.999701                       -0.999748
# 4                       -0.999988                       -0.999969
#
#    fBodyGyro-bandsEnergy()-41,482  fBodyGyro-bandsEnergy()-49,562  \
# 0                       -0.978335                       -0.964975
# 1                       -0.943672                       -0.961896
# 2                       -0.999973                       -0.999968
# 3                       -0.999550                       -0.999289
# 4                       -0.999937                       -0.999960
#
#    fBodyGyro-bandsEnergy()-57,642  fBodyGyro-bandsEnergy()-1,162  \
# 0                       -0.999986                      -0.867565
# 1                       -0.960682                      -0.906103
# 2                       -0.999986                      -0.999293
# 3                       -0.999612                      -0.994088
# 4                       -0.999987                      -0.999709
#
#    fBodyGyro-bandsEnergy()-17,322  fBodyGyro-bandsEnergy()-33,482  \
# 0                       -0.934318                       -0.987111
# 1                       -0.964709                       -0.974651
# 2                       -0.999965                       -0.999977
# 3                       -0.999703                       -0.999705
# 4                       -0.999963                       -0.999963
#
#    fBodyGyro-bandsEnergy()-49,642  fBodyGyro-bandsEnergy()-1,242  \
# 0                       -0.975380                      -0.848466
# 1                       -0.956184                      -0.900946
# 2                       -0.999971                      -0.999330
# 3                       -0.999332                      -0.994406
# 4                       -0.999966                      -0.999713
#
#    fBodyGyro-bandsEnergy()-25,482  fBodyGyro-bandsEnergy()-1,81  \
# 0                       -0.970622                     -0.804182
# 1                       -0.961368                     -0.835462
# 2                       -0.999975                     -0.999857
# 3                       -0.999679                     -0.891072
# 4                       -0.999980                     -0.999249
#
#    fBodyGyro-bandsEnergy()-9,161  fBodyGyro-bandsEnergy()-17,241  \
# 0                      -0.658185                       -0.597712
# 1                      -0.929302                       -0.882820
# 2                      -0.999952                       -0.999877
# 3                      -0.998805                       -0.998185
# 4                      -0.999947                       -0.999915
#
#    fBodyGyro-bandsEnergy()-25,321  fBodyGyro-bandsEnergy()-33,401  \
# 0                       -0.916975                       -0.959830
# 1                       -0.924309                       -0.933233
# 2                       -0.999932                       -0.999849
# 3                       -0.999054                       -0.998807
# 4                       -0.999957                       -0.999978
#
#    fBodyGyro-bandsEnergy()-41,481  fBodyGyro-bandsEnergy()-49,561  \
# 0                       -0.937139                       -0.959351
# 1                       -0.981489                       -0.921534
# 2                       -0.999854                       -0.999762
# 3                       -0.997956                       -0.996972
# 4                       -0.999908                       -0.999897
#
#    fBodyGyro-bandsEnergy()-57,641  fBodyGyro-bandsEnergy()-1,161  \
# 0                       -0.998453                      -0.699203
# 1                       -0.975429                      -0.819780
# 2                       -0.999757                      -0.999850
# 3                       -0.997354                      -0.895968
# 4                       -0.999937                      -0.999270
#
#    fBodyGyro-bandsEnergy()-17,321  fBodyGyro-bandsEnergy()-33,481  \
# 0                       -0.576195                       -0.953577
# 1                       -0.851621                       -0.946011
# 2                       -0.999852                       -0.999856
# 3                       -0.997814                       -0.998580
# 4                       -0.999901                       -0.999965
#
#    fBodyGyro-bandsEnergy()-49,641  fBodyGyro-bandsEnergy()-1,241  \
# 0                       -0.976352                      -0.646565
# 1                       -0.944966                      -0.804884
# 2                       -0.999760                      -0.999836
# 3                       -0.997138                      -0.896216
# 4                       -0.999915                      -0.999264
#
#    fBodyGyro-bandsEnergy()-25,481  fBodyAccMag-mean()  fBodyAccMag-std()  \
# 0                       -0.928334           -0.000045          -0.064379
# 1                       -0.931044           -0.334282          -0.500465
# 2                       -0.999910           -0.978094          -0.956100
# 3                       -0.998909           -0.204939           0.602066
# 4                       -0.999961           -0.973345          -0.953435
#
#    fBodyAccMag-mad()  fBodyAccMag-max()  fBodyAccMag-min()  fBodyAccMag-sma()  \
# 0           0.038974          -0.363217          -0.848814          -0.000045
# 1          -0.403658          -0.656353          -0.909249          -0.334282
# 2          -0.971824          -0.951873          -0.978923          -0.978094
# 3           0.015803           0.667114          -0.046228          -0.204939
# 4          -0.963626          -0.950588          -0.998247          -0.973345
#
#    fBodyAccMag-energy()  fBodyAccMag-iqr()  fBodyAccMag-entropy()  \
# 0             -0.426669          -0.380682               0.629278
# 1             -0.802221          -0.479647               0.516770
# 2             -0.998780          -0.990515              -0.853531
# 3              0.210221          -0.784040               0.020624
# 4             -0.998595          -0.976485              -0.790533
#
#    fBodyAccMag-maxInds  fBodyAccMag-meanFreq()  fBodyAccMag-skewness()  \
# 0            -0.793103               -0.073735               -0.329307
# 1            -0.448276                0.166638               -0.441132
# 2            -1.000000               -0.148030                0.691818
# 3            -1.000000               -0.494131                0.817055
# 4            -1.000000               -0.265757                0.518857
#
#    fBodyAccMag-kurtosis()  fBodyBodyAccJerkMag-mean()  \
# 0               -0.697269                   -0.048810
# 1               -0.751044                   -0.311556
# 2                0.585753                   -0.993907
# 3                0.746555                   -0.907234
# 4                0.372470                   -0.989230
#
#    fBodyBodyAccJerkMag-std()  fBodyBodyAccJerkMag-mad()  \
# 0                  -0.048062                  -0.074519
# 1                  -0.503373                  -0.437793
# 2                  -0.993988                  -0.993291
# 3                  -0.894098                  -0.895614
# 4                  -0.991054                  -0.989044
#
#    fBodyBodyAccJerkMag-max()  fBodyBodyAccJerkMag-min()  \
# 0                  -0.101867                  -0.898635
# 1                  -0.554613                  -0.531223
# 2                  -0.994862                  -0.988823
# 3                  -0.915933                  -0.949541
# 4                  -0.992235                  -0.976060
#
#    fBodyBodyAccJerkMag-sma()  fBodyBodyAccJerkMag-energy()  \
# 0                  -0.048810                     -0.538784
# 1                  -0.311556                     -0.807196
# 2                  -0.993907                     -0.999922
# 3                  -0.907234                     -0.994120
# 4                  -0.989230                     -0.999846
#
#    fBodyBodyAccJerkMag-iqr()  fBodyBodyAccJerkMag-entropy()  \
# 0                  -0.382790                       0.455864
# 1                  -0.485293                       0.214852
# 2                  -0.995761                      -1.000000
# 3                  -0.933865                      -0.548877
# 4                  -0.988786                      -1.000000
#
#    fBodyBodyAccJerkMag-maxInds  fBodyBodyAccJerkMag-meanFreq()  \
# 0                    -0.904762                       -0.081377
# 1                    -0.904762                        0.261071
# 2                    -0.746032                        0.422548
# 3                    -1.000000                       -0.259205
# 4                    -0.619048                        0.348653
#
#    fBodyBodyAccJerkMag-skewness()  fBodyBodyAccJerkMag-kurtosis()  \
# 0                        0.093411                       -0.267289
# 1                       -0.235047                       -0.565069
# 2                       -0.515670                       -0.843715
# 3                       -0.006273                       -0.463502
# 4                       -0.592880                       -0.853811
#
#    fBodyBodyGyroMag-mean()  fBodyBodyGyroMag-std()  fBodyBodyGyroMag-mad()  \
# 0                -0.369867               -0.416962               -0.305015
# 1                -0.558633               -0.650492               -0.592625
# 2                -0.983457               -0.974615               -0.977895
# 3                -0.785936               -0.429150               -0.614462
# 4                -0.986184               -0.981817               -0.982090
#
#    fBodyBodyGyroMag-max()  fBodyBodyGyroMag-min()  fBodyBodyGyroMag-sma()  \
# 0               -0.617360               -0.954222               -0.369867
# 1               -0.715308               -0.811548               -0.558633
# 2               -0.972029               -0.997281               -0.983457
# 3               -0.327070               -0.981428               -0.785936
# 4               -0.982487               -0.996383               -0.986184
#
#    fBodyBodyGyroMag-energy()  fBodyBodyGyroMag-iqr()  \
# 0                  -0.773743               -0.267837
# 1                  -0.905259               -0.620147
# 2                  -0.999617               -0.986670
# 3                  -0.865870               -0.921098
# 4                  -0.999772               -0.988076
#
#    fBodyBodyGyroMag-entropy()  fBodyBodyGyroMag-maxInds  \
# 0                    0.575735                 -0.384615
# 1                    0.516492                 -0.846154
# 2                   -0.678570                 -0.948718
# 3                   -0.102993                 -1.000000
# 4                   -0.735639                 -1.000000
#
#    fBodyBodyGyroMag-meanFreq()  fBodyBodyGyroMag-skewness()  \
# 0                    -0.061643                    -0.585303
# 1                     0.164972                    -0.535354
# 2                    -0.269956                     0.114107
# 3                    -0.898204                     0.606371
# 4                    -0.175869                    -0.229978
#
#    fBodyBodyGyroMag-kurtosis()  fBodyBodyGyroJerkMag-mean()  \
# 0                    -0.873943                    -0.510536
# 1                    -0.821282                    -0.634925
# 2                    -0.215179                    -0.993907
# 3                     0.386821                    -0.944109
# 4                    -0.599693                    -0.993098
#
#    fBodyBodyGyroJerkMag-std()  fBodyBodyGyroJerkMag-mad()  \
# 0                   -0.492168                   -0.501917
# 1                   -0.662567                   -0.618078
# 2                   -0.994560                   -0.992626
# 3                   -0.952727                   -0.943451
# 4                   -0.994471                   -0.994212
#
#    fBodyBodyGyroJerkMag-max()  fBodyBodyGyroJerkMag-min()  \
# 0                   -0.438247                   -0.657221
# 1                   -0.707434                   -0.877264
# 2                   -0.996038                   -0.998112
# 3                   -0.956681                   -0.948259
# 4                   -0.994619                   -0.996161
#
#    fBodyBodyGyroJerkMag-sma()  fBodyBodyGyroJerkMag-energy()  \
# 0                   -0.510536                      -0.867093
# 1                   -0.634925                      -0.932757
# 2                   -0.993907                      -0.999965
# 3                   -0.944109                      -0.998396
# 4                   -0.993098                      -0.999960
#
#    fBodyBodyGyroJerkMag-iqr()  fBodyBodyGyroJerkMag-entropy()  \
# 0                   -0.482046                        0.397399
# 1                   -0.583846                        0.369093
# 2                   -0.989453                       -1.000000
# 3                   -0.927869                       -0.431083
# 4                   -0.994666                       -0.955696
#
#    fBodyBodyGyroJerkMag-maxInds  fBodyBodyGyroJerkMag-meanFreq()  \
# 0                     -0.904762                         0.031612
# 1                     -0.904762                         0.033365
# 2                     -0.777778                         0.297890
# 3                     -1.000000                         0.156408
# 4                     -0.936508                         0.252008
#
#    fBodyBodyGyroJerkMag-skewness()  fBodyBodyGyroJerkMag-kurtosis()  \
# 0                         0.219114                        -0.058133
# 1                        -0.335527                        -0.693933
# 2                        -0.718256                        -0.928165
# 3                        -0.412991                        -0.718527
# 4                        -0.372861                        -0.707732
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                     0.198542                             -0.628340
# 1                    -0.698096                             -0.302643
# 2                    -0.014493                              0.004535
# 3                     0.249525                              0.440171
# 4                     0.033104                              0.044180
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                          0.923325                             -0.817575
# 1                          0.082083                              0.201727
# 2                         -0.005036                             -0.050323
# 3                         -0.007508                              0.343715
# 4                         -0.215201                              0.374553
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 0             -0.718848              0.292296              0.011294
# 1             -0.776663              0.232799              0.095748
# 2             -0.762283              0.010403             -0.129243
# 3              0.683948             -0.505728             -0.495238
# 4             -0.929185              0.084946              0.069420
#
#    subject_id  activity     activity_name
# 0           6         2  WALKING_UPSTAIRS
# 1          28         1           WALKING
# 2          26         4           SITTING
# 3          25         6             LYING
# 4           3         4           SITTING

# %%
train_data.columns
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'angle(tBodyAccMean,gravity)', 'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject_id',
#        'activity', 'activity_name'],
#       dtype='object', length=564)

# %% [raw]
# train_data.describe()

# %%
train_data['activity'].unique()
# Out:
# array([2, 1, 4, 6, 3, 5])

# %%
train_data['activity'].value_counts().sort_values().plot(kind = 'bar', color = 'pink')
# Out:
# <Axes: xlabel='activity'>

# %% [markdown]
# ## Preparing Train And Test Data

# %%
x_train, y_train = train_data.iloc[:, :-2], train_data.iloc[:, -1:]
x_test, y_test = test_data.iloc[:, :-2], test_data.iloc[:, -1:]
x_train.shape, y_train.shape
# Out:
# ((7352, 562), (7352, 1))

# %%
x_test, y_test = test_data.iloc[:, :-2], test_data.iloc[:, -1:]
x_test.shape, y_test.shape
# Out:
# ((2947, 562), (2947, 1))

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.fit_transform(y_test)

# %%
x_test.shape, y_test.shape, x_train.shape, y_train.shape
# Out:
# ((2947, 562), (2947,), (7352, 562), (7352,))

# %%
scaling_data = MinMaxScaler()
x_train = scaling_data.fit_transform(x_train)
x_test = scaling_data.transform(x_test)

# %% [markdown]
# ## Creating A Base Model

# %%
model = Sequential()
model.add(Dense(units=64,kernel_initializer='normal',activation='sigmoid',input_dim=x_train.shape[1]))
model.add(Dropout(0.2))
model.add(Dense(units=6,kernel_initializer='normal',activation='softmax'))
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size = 64, epochs= 10,validation_data = (x_test,y_test))
# Out:
# Epoch 1/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3867 - loss: 1.5114 - val_accuracy: 0.7119 - val_loss: 1.0319
# Epoch 2/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6918 - loss: 0.9509 - val_accuracy: 0.8202 - val_loss: 0.7178
# Epoch 3/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8052 - loss: 0.6532 - val_accuracy: 0.8232 - val_loss: 0.5280
# Epoch 4/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8575 - loss: 0.4859 - val_accuracy: 0.8887 - val_loss: 0.4148
# Epoch 5/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8832 - loss: 0.3912 - val_accuracy: 0.9002 - val_loss: 0.3575
# Epoch 6/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9022 - loss: 0.3224 - val_accuracy: 0.9104 - val_loss: 0.3068
# Epoch 7/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9011 - loss: 0.2823 - val_accuracy: 0.9233 - val_loss: 0.2625
# Epoch 8/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9177 - loss: 0.2539 - val_accuracy: 0.9158 - val_loss: 0.2480
# Epoch 9/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9237 - loss: 0.2247 - val_accuracy: 0.9155 - val_loss: 0.2292
# Epoch 10/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9309 - loss: 0.2036 - val_accuracy: 0.9277 - val_loss: 0.2102

# %% [markdown]
# ## Hypertuning The Model

# %%
def build_model(hp):
    model = keras.Sequential()
    for i in range(hp.Int('num_layers', 2, 25)):
        model.add(layers.Dense(units = hp.Int('units' + str(i), min_value=32, max_value=512, step=32),
                               kernel_initializer= hp.Choice('initializer', ['uniform', 'normal']),
                               activation= hp.Choice('activation', ['relu', 'sigmoid', 'tanh'])))
    model.add(layers.Dense(6, kernel_initializer= hp.Choice('initializer', ['uniform', 'normal']), activation='softmax'))
    model.add(
            Dropout(0.2))
    model.compile(
        optimizer = 'adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy'])
    return model


tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials= 5,
    executions_per_trial=3,
    directory='project', project_name = 'Human_activity_recognition')

tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 5
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 25, 'step': 1, 'sampling': 'linear'}
# units0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# initializer (Choice)
# {'default': 'uniform', 'conditions': [], 'values': ['uniform', 'normal'], 'ordered': False}
# activation (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'sigmoid', 'tanh'], 'ordered': False}
# units1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}

# %%
tuner.search(x_train, y_train,
             epochs= 10,
             validation_data=(x_test, y_test))
# Out:
# Trial 5 Complete [00h 02m 48s]
# val_accuracy: 0.41239677866299945
#
# Best val_accuracy So Far: 0.9238773981730143
# Total elapsed time: 00h 08m 50s

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project/Human_activity_recognition
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 1 summary
# Hyperparameters:
# num_layers: 5
# units0: 512
# initializer: normal
# activation: tanh
# units1: 224
# units2: 384
# units3: 352
# units4: 64
# units5: 288
# units6: 288
# units7: 32
# units8: 64
# units9: 320
# Score: 0.9238773981730143
#
# Trial 4 summary
# Hyperparameters:
# num_layers: 13
# units0: 224
# initializer: uniform
# activation: relu
# units1: 384
# units2: 352
# units3: 480
# units4: 192
# units5: 64
# units6: 160
# units7: 448
# units8: 256
# units9: 192
# units10: 416
# units11: 448
# units12: 96
# units13: 160
# Score: 0.41239677866299945
#
# Trial 0 summary
# Hyperparameters:
# num_layers: 10
# units0: 288
# initializer: uniform
# activation: tanh
# units1: 480
# units2: 32
# units3: 32
# units4: 32
# units5: 32
# units6: 32
# units7: 32
# units8: 32
# units9: 32
# Score: 0.3432869513829549
#
# Trial 2 summary
# Hyperparameters:
# num_layers: 14
# units0: 288
# initializer: uniform
# activation: tanh
# units1: 352
# units2: 128
# units3: 256
# units4: 224
# units5: 352
# units6: 32
# units7: 224
# units8: 160
# units9: 480
# units10: 32
# units11: 32
# units12: 32
# units13: 32
# Score: 0.2077819307645162
#
# Trial 3 summary
# Hyperparameters:
# num_layers: 10
# units0: 288
# initializer: uniform
# activation: sigmoid
# units1: 128
# units2: 512
# units3: 320
# units4: 480
# units5: 64
# units6: 512
# units7: 32
# units8: 320
# units9: 128
# units10: 160
# units11: 256
# units12: 480
# units13: 256
# Score: 0.18221920728683472

# %%
model=tuner.get_best_models(num_models=1)[0]
history = model.fit(x_train,y_train, epochs=51, validation_data=(x_test,y_test))
# Out:
# Epoch 1/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7385 - loss: 1.1852 - val_accuracy: 0.7733 - val_loss: 0.8884
# Epoch 2/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7227 - loss: 1.1744 - val_accuracy: 0.8992 - val_loss: 0.6239
# Epoch 3/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7472 - loss: 1.1497 - val_accuracy: 0.8293 - val_loss: 0.7265
# Epoch 4/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7269 - loss: 1.2249 - val_accuracy: 0.8558 - val_loss: 1.0214
# Epoch 5/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7500 - loss: 1.1650 - val_accuracy: 0.9247 - val_loss: 0.4552
# Epoch 6/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7495 - loss: 1.1081 - val_accuracy: 0.9410 - val_loss: 0.4508
# Epoch 7/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7513 - loss: 1.1655 - val_accuracy: 0.9257 - val_loss: 0.5043
# Epoch 8/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7562 - loss: 0.9288 - val_accuracy: 0.9243 - val_loss: 0.7112
# Epoch 9/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7648 - loss: 0.9170 - val_accuracy: 0.9396 - val_loss: 0.5525
# Epoch 10/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7745 - loss: 0.8297 - val_accuracy: 0.9362 - val_loss: 0.7921
# Epoch 11/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7611 - loss: 0.9731 - val_accuracy: 0.9165 - val_loss: 0.7204
# Epoch 12/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.7553 - loss: 1.0670 - val_accuracy: 0.9118 - val_loss: 1.0159
# Epoch 13/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7535 - loss: 1.0612 - val_accuracy: 0.9077 - val_loss: 1.1358
# Epoch 14/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7716 - loss: 0.8177 - val_accuracy: 0.8704 - val_loss: 1.0170
# Epoch 15/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7666 - loss: 0.7771 - val_accuracy: 0.9294 - val_loss: 0.7809
# Epoch 16/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7728 - loss: 0.8429 - val_accuracy: 0.8839 - val_loss: 1.3011
# Epoch 17/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7507 - loss: 0.9452 - val_accuracy: 0.8989 - val_loss: 0.5778
# Epoch 18/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7673 - loss: 0.9420 - val_accuracy: 0.9481 - val_loss: 0.5989
# Epoch 19/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7628 - loss: 0.9387 - val_accuracy: 0.9274 - val_loss: 0.7512
# Epoch 20/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7664 - loss: 0.8309 - val_accuracy: 0.9006 - val_loss: 1.0363
# Epoch 21/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7711 - loss: 0.7778 - val_accuracy: 0.8931 - val_loss: 1.1581
# Epoch 22/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7547 - loss: 0.8165 - val_accuracy: 0.9511 - val_loss: 0.5382
# Epoch 23/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7699 - loss: 0.7466 - val_accuracy: 0.9311 - val_loss: 0.8296
# Epoch 24/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7813 - loss: 0.7072 - val_accuracy: 0.9135 - val_loss: 0.9279
# Epoch 25/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7709 - loss: 0.8395 - val_accuracy: 0.9332 - val_loss: 0.5544
# Epoch 26/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7778 - loss: 0.7075 - val_accuracy: 0.9410 - val_loss: 0.5975
# Epoch 27/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7754 - loss: 0.7754 - val_accuracy: 0.9457 - val_loss: 0.6056
# Epoch 28/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7667 - loss: 0.8310 - val_accuracy: 0.9131 - val_loss: 0.9732
# Epoch 29/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7725 - loss: 0.8309 - val_accuracy: 0.9416 - val_loss: 0.7390
# Epoch 30/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7839 - loss: 0.7029 - val_accuracy: 0.8707 - val_loss: 1.7657
# Epoch 31/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7633 - loss: 1.1250 - val_accuracy: 0.9399 - val_loss: 0.5454
# Epoch 32/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7626 - loss: 0.7418 - val_accuracy: 0.9301 - val_loss: 0.7527
# Epoch 33/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7289 - loss: 1.3465 - val_accuracy: 0.9362 - val_loss: 0.7008
# Epoch 34/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7631 - loss: 0.7743 - val_accuracy: 0.9457 - val_loss: 0.4301
# Epoch 35/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7680 - loss: 0.8055 - val_accuracy: 0.9050 - val_loss: 1.1367
# Epoch 36/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7592 - loss: 0.8323 - val_accuracy: 0.9444 - val_loss: 0.7283
# Epoch 37/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7758 - loss: 0.6811 - val_accuracy: 0.9586 - val_loss: 0.3597
# Epoch 38/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.7815 - loss: 0.6231 - val_accuracy: 0.9559 - val_loss: 0.4274
# Epoch 39/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7706 - loss: 0.7403 - val_accuracy: 0.9372 - val_loss: 0.7884
# Epoch 40/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.7891 - loss: 0.6738 - val_accuracy: 0.9562 - val_loss: 0.4245
# Epoch 41/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.7805 - loss: 0.6726 - val_accuracy: 0.9369 - val_loss: 0.5749
# Epoch 42/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.7701 - loss: 0.7107 - val_accuracy: 0.9460 - val_loss: 0.7254
# Epoch 43/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.7754 - loss: 0.9469 - val_accuracy: 0.9335 - val_loss: 0.7887
# Epoch 44/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7681 - loss: 0.6812 - val_accuracy: 0.9511 - val_loss: 0.5910
# Epoch 45/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7868 - loss: 0.6287 - val_accuracy: 0.9247 - val_loss: 0.8671
# Epoch 46/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7810 - loss: 0.7998 - val_accuracy: 0.9406 - val_loss: 0.6976
# Epoch 47/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7852 - loss: 0.6526 - val_accuracy: 0.9074 - val_loss: 1.2358
# Epoch 48/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7673 - loss: 0.9125 - val_accuracy: 0.9009 - val_loss: 1.1202
# Epoch 49/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7776 - loss: 0.7022 - val_accuracy: 0.9389 - val_loss: 0.6461
# Epoch 50/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7819 - loss: 0.6964 - val_accuracy: 0.9053 - val_loss: 1.0910
# Epoch 51/51
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7881 - loss: 0.7071 - val_accuracy: 0.9237 - val_loss: 0.9445

# %%
model.summary()
import tensorflow as tf

from tensorflow import keras

Callback = tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=3)
mo_fitt = model.fit(x_train,y_train, epochs=200, validation_data=(x_test,y_test), callbacks=Callback)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │       288,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 224)            │       114,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 384)            │        86,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 352)            │       135,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │        22,592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 6)              │           390 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 6)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,944,212 (7.42 MB)
#  Trainable params: 648,070 (2.47 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,296,142 (4.94 MB)
# Epoch 1/200
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7798 - loss: 0.7611 - val_accuracy: 0.9077 - val_loss: 1.0362
# Epoch 2/200
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.7751 - loss: 0.7352 - val_accuracy: 0.9376 - val_loss: 0.4772
# Epoch 3/200
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7757 - loss: 0.7176 - val_accuracy: 0.9053 - val_loss: 0.9036
# Epoch 4/200
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7571 - loss: 0.9733 - val_accuracy: 0.9301 - val_loss: 0.7704
# Epoch 5/200
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7844 - loss: 0.6187 - val_accuracy: 0.9559 - val_loss: 0.4178
# Epoch 6/200
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7775 - loss: 0.7035 - val_accuracy: 0.9569 - val_loss: 0.5198
# Epoch 7/200
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7799 - loss: 0.6276 - val_accuracy: 0.9342 - val_loss: 0.6226
# Epoch 8/200
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7774 - loss: 0.7310 - val_accuracy: 0.9586 - val_loss: 0.4817
# Epoch 9/200
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7842 - loss: 0.6179 - val_accuracy: 0.9433 - val_loss: 0.6735
# Epoch 10/200
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.7794 - loss: 0.7909 - val_accuracy: 0.9532 - val_loss: 0.5154
# Epoch 11/200
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7678 - loss: 0.6972 - val_accuracy: 0.8527 - val_loss: 1.5533

# %%
accuracy = mo_fitt.history['accuracy']
loss = mo_fitt.history['loss']
validation_loss = mo_fitt.history['val_loss']
validation_accuracy = mo_fitt.history['val_accuracy']


plt.figure(figsize=(15, 7))
plt.subplot(2, 2, 1)
plt.plot(range(11), accuracy, label='Training Accuracy')
plt.plot(range(11), validation_accuracy, label='Validation Accuracy')
plt.legend(loc='upper left')
plt.title('Accuracy : Training Vs Validation ')



plt.subplot(2, 2, 2)
plt.plot(range(11), loss, label='Training Loss')
plt.plot(range(11), validation_loss, label='Validation Loss')
plt.title('Loss : Training Vs Validation ')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## Conclusion :
#
# > After hypertuning the model, it is found out that 4 layers should be there.
# > Final accuracy achieved is 0.9518.

# %%
model
# Out:
# <Sequential name=sequential, built=True>
